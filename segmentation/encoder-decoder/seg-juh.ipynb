# %%
import os
import glob
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import cv2
from skimage.transform import resize

SEGMENTATION_MODEL_PATH = "/home/furix/Desktop/DiscAI/notebooks/segmentation_model_best.keras"
IMAGE_DIR = "../data/JUH/train/images" 
OUTPUT_MASK_DIR = "../data/JUH_segmentation_output/train_masks" 
OUTPUT_PREPROCESS_DIR = "../data/JUH_segmentation_output/train_preprocessed" 

SAVE_MASKS = True
DISPLAY_IMAGES = False
SAVE_PREPROCESS = True

PRE_CROP_TARGET_SHAPE = (512, 512)
CROP_Y_START = 96
CROP_X_START = 48
CROP_X_END_OFFSET = -48
FINAL_INPUT_SHAPE = (
    PRE_CROP_TARGET_SHAPE[0] - CROP_Y_START,
    PRE_CROP_TARGET_SHAPE[1] - CROP_X_START - abs(CROP_X_END_OFFSET)
) 
PREDICTION_THRESHOLD = 0.5

print("Configuring GPU...")

gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus: tf.config.experimental.set_memory_growth(gpu, True)
        print(f"TensorFlow GPU memory growth enabled for {len(gpus)} GPU(s).")
    except RuntimeError as e: print(f"Error setting memory growth: {e}")
else: print("No GPU detected by TensorFlow.")


@tf.keras.utils.register_keras_serializable()
def dice_loss(y_true, y_pred, epsilon=1e-6): y_true = tf.cast(y_true, tf.float32); y_pred = tf.cast(y_pred, tf.float32); intersection = tf.reduce_sum(y_true * y_pred); union = tf.reduce_sum(y_true) + tf.reduce_sum(y_pred); return 1 - (2. * intersection + epsilon) / (union + epsilon)
@tf.keras.utils.register_keras_serializable()
def combo_loss(y_true, y_pred): y_true_f = tf.cast(y_true, tf.float32); y_pred_f = tf.cast(y_pred, tf.float32); bce = tf.keras.losses.binary_crossentropy(y_true_f, y_pred_f); dsc = dice_loss(y_true_f, y_pred_f); return bce + dsc
@tf.keras.utils.register_keras_serializable()
def dice_coefficient(y_true, y_pred, epsilon=1e-6): y_true = tf.cast(y_true, tf.float32); y_pred = tf.cast(y_pred, tf.float32); intersection = tf.reduce_sum(y_true * y_pred); union = tf.reduce_sum(y_true) + tf.reduce_sum(y_pred); dice = tf.where(union == 0, 1.0, (2. * intersection + epsilon) / (union + epsilon)); return dice
@tf.keras.utils.register_keras_serializable()
def iou_metric(y_true, y_pred, epsilon=1e-6): y_true = tf.cast(y_true, tf.float32); y_pred = tf.cast(y_pred, tf.float32); intersection = tf.reduce_sum(y_true * y_pred); union = tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) - intersection; iou = tf.where(union == 0, 1.0, (intersection + epsilon) / (union + epsilon)); return iou
@tf.keras.utils.register_keras_serializable()
def channel_avg_pool(x): return tf.reduce_mean(x, axis=-1, keepdims=True)
@tf.keras.utils.register_keras_serializable()
def channel_max_pool(x): return tf.reduce_max(x, axis=-1, keepdims=True)

def normalize_image(image_slice_np):
    slice_float = image_slice_np.astype(np.float32); min_val, max_val = np.min(slice_float), np.max(slice_float)
    if max_val > min_val: normalized_slice = (slice_float - min_val) / (max_val - min_val)
    else: normalized_slice = np.zeros_like(slice_float)
    return normalized_slice

def preprocess_and_crop_image_for_inference(image_path, pre_crop_shape=PRE_CROP_TARGET_SHAPE, final_shape=FINAL_INPUT_SHAPE):
    try:
        img_np = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
        if img_np is None: print(f"Warning: Could not read image {image_path}. Skipping."); return None
        resized_slice = resize(img_np, pre_crop_shape, order=3, preserve_range=True, anti_aliasing=True)
        normalized_slice = normalize_image(resized_slice)
        cropped_slice = normalized_slice[CROP_Y_START:, CROP_X_START:CROP_X_END_OFFSET]
        if cropped_slice.shape != final_shape: print(f"Warning: Cropped shape {cropped_slice.shape} for {image_path} != expected {final_shape}.")
        final_tensor = np.expand_dims(cropped_slice, axis=-1); final_tensor = np.expand_dims(final_tensor, axis=0)
        return final_tensor.astype(np.float32)
    except Exception as e: print(f"Error preprocessing {image_path}: {e}"); return None

def generate_segmentation_mask(input_tensor, model, threshold=PREDICTION_THRESHOLD):
    if model is None: raise ValueError("Segmentation model is not loaded.");
    if input_tensor is None: raise ValueError("Input tensor is None.")
    try:
        if input_tensor.shape[1:] != model.input_shape[1:]: print(f"Warning: Input tensor shape {input_tensor.shape[1:]} differs from model expected {model.input_shape[1:]}.")
        prediction = model.predict(input_tensor, verbose=0)
        if prediction.ndim == 4 and prediction.shape[0] == 1 and prediction.shape[-1] == 1: mask = (prediction[0, ..., 0] > threshold).astype(np.uint8); return mask
        else: print(f"Error: Unexpected prediction output shape: {prediction.shape}"); return None
    except Exception as e: print(f"Error during segmentation prediction: {e}"); return None

if __name__ == "__main__":
    print(f"Loading segmentation model from: {SEGMENTATION_MODEL_PATH}")
    if not os.path.exists(SEGMENTATION_MODEL_PATH): print(f"FATAL: Model file not found. Exiting."); exit(1)
    try:
        custom_objects = { 'dice_loss': dice_loss, 'combo_loss': combo_loss, 'dice_coefficient': dice_coefficient, 'iou_metric': iou_metric, 'channel_avg_pool': channel_avg_pool, 'channel_max_pool': channel_max_pool }
        segmentation_model = tf.keras.models.load_model(SEGMENTATION_MODEL_PATH, custom_objects=custom_objects)
        print("Segmentation model loaded successfully.")
        print(f"Model expects input shape (HxWxC): {segmentation_model.input_shape[1:]}")
        if segmentation_model.input_shape[1:3] != FINAL_INPUT_SHAPE: print(f"WARNING: Model expects {segmentation_model.input_shape[1:3]} but preprocessing generates {FINAL_INPUT_SHAPE}.")
    except Exception as e: print(f"FATAL: Error loading segmentation model: {e}"); exit(1)

    if SAVE_MASKS:
        os.makedirs(OUTPUT_MASK_DIR, exist_ok=True)
        print(f"Output masks will be saved to: {OUTPUT_MASK_DIR}")

    print(f"Searching for images in: {IMAGE_DIR}")
    image_files = glob.glob(os.path.join(IMAGE_DIR, '*.jpg')) + \
                  glob.glob(os.path.join(IMAGE_DIR, '*.jpeg')) + \
                  glob.glob(os.path.join(IMAGE_DIR, '*.png'))
    if not image_files: print(f"FATAL: No JPG or PNG images found in {IMAGE_DIR}. Exiting."); exit(1)
    print(f"Found {len(image_files)} images to process.")

    processed_count = 0
    skipped_count = 0
    for img_path in image_files:
        base_filename = os.path.basename(img_path)

        if base_filename.lower().startswith('x'):
            print(f"Skipping file: {base_filename} (starts with 'x')")
            skipped_count += 1
            continue 

        print(f"\nProcessing: {base_filename}")

        input_tensor = preprocess_and_crop_image_for_inference(img_path)
        if input_tensor is None:
            continue

        print(f"  Preprocessed input tensor shape: {input_tensor.shape}")

        mask = generate_segmentation_mask(input_tensor, segmentation_model)
        if mask is None:
            print(f"  Segmentation failed for {base_filename}")
            continue

        print(f"  Generated mask shape: {mask.shape}")
        processed_count += 1

        if SAVE_MASKS:
            try:
                mask_filename = f"mask_{os.path.splitext(base_filename)[0]}.png"
                output_path = os.path.join(OUTPUT_MASK_DIR, mask_filename)
                cv2.imwrite(output_path, mask * 255)
                print(f"  Saved mask to: {output_path}")
            except Exception as e:
                print(f"  Error saving mask for {base_filename}: {e}")
                
        if SAVE_PREPROCESS and input_tensor is not None: 
            try:
                os.makedirs(OUTPUT_PREPROCESS_DIR, exist_ok=True)

                preprocess_filename = f"preprocess_{os.path.splitext(base_filename)[0]}.png"
                output_path = os.path.join(OUTPUT_PREPROCESS_DIR, preprocess_filename)

                image_to_save = np.squeeze(input_tensor)

                image_to_save_uint8 = (image_to_save * 255.0).astype(np.uint8)

                cv2.imwrite(output_path, image_to_save_uint8)
                print(f"  Saved preprocessed image to: {output_path}")

            except Exception as e:
                print(f"  Error saving preprocessed image for {base_filename}: {e}")

        if DISPLAY_IMAGES:
            try:
                original_img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
                plt.figure(figsize=(10, 5)); plt.subplot(1, 2, 1); plt.imshow(original_img, cmap='gray'); plt.title(f"Original: {base_filename}"); plt.axis("off");
                plt.subplot(1, 2, 2); plt.imshow(mask, cmap='gray'); plt.title("Generated Mask"); plt.axis("off"); plt.show()
            except Exception as e: print(f"  Error displaying image/mask for {base_filename}: {e}")

    print(f"\nFinished processing. Processed: {processed_count}, Skipped: {skipped_count}")
# Out:
# Configuring GPU...
# TensorFlow GPU memory growth enabled for 1 GPU(s).
# Loading segmentation model from: /home/furix/Desktop/DiscAI/notebooks/segmentation_model_best.keras
# Segmentation model loaded successfully.
# Model expects input shape (HxWxC): (416, 416, 1)
# Output masks will be saved to: ../data/JUH_segmentation_output/train_masks
# Searching for images in: ../data/JUH/train/images
# Found 2918 images to process.
#
# Processing: S273588_jpg.rf.ca89534b63a7755dddf3bbad66d3ba10.jpg
#   Preprocessed input tensor shape: (1, 416, 416, 1)
#   Generated mask shape: (416, 416)
#   Saved mask to: ../data/JUH_segmentation_output/train_masks/mask_S273588_jpg.rf.ca89534b63a7755dddf3bbad66d3ba10.png
#   Saved preprocessed image to: ../data/JUH_segmentation_output/train_preprocessed/preprocess_S273588_jpg.rf.ca89534b63a7755dddf3bbad66d3ba10.png
# Skipping file: X1355114_L2_jpg.rf.38bfbd9b3279773d5c48d10b82600cc7.jpg (starts with 'x')
#
# Processing: S863745_jpg.rf.68672ffa4072173a96f85a6856f29f3b.jpg
#   Preprocessed input tensor shape: (1, 416, 416, 1)
#   Generated mask shape: (416, 416)
#   Saved mask to: ../data/JUH_segmentation_output/train_masks/mask_S863745_jpg.rf.68672ffa4072173a96f85a6856f29f3b.png
#   Saved preprocessed image to: ../data/JUH_segmentation_output/train_preprocessed/preprocess_S863745_jpg.rf.68672ffa4072173a96f85a6856f29f3b.png
# Skipping file: X477841_L1_jpg.rf.3f9c8c99e0b7e236c8bb21c326ff25d9.jpg (starts with 'x')
# Skipping file: X749453_L3_jpg.rf.5155ebf3c41ae43c291ac131afb5a463.jpg (starts with 'x')
# Skipping file: X1154830_L1_jpg.rf.2f42347817b9703df35f1f90b8de3c3f.jpg (starts with 'x')
#
# Processing: s311709-L5_jpg.rf.ba26242923e5d12c367fc47d3839ce4f.jpg
#   Preprocessed input tensor shape: (1, 416, 416, 1)
#   Generated mask shape: (416, 416)
#   Saved mask to: ../data/JUH_segmentation_output/train_masks/mask_s311709-L5_jpg.rf.ba26242923e5d12c367fc47d3839ce4f.png
#   Saved preprocessed image to: ../data/JUH_segmentation_output/train_preprocessed/preprocess_
png
#   Saved preprocessed image to: ../data/JUH_segmentation_output/train_preprocessed/preprocess_S1238239_jpg.rf.2f3568906fa7af03a15d44fd1a3554d6.png
# Skipping file: x606966-L2_jpg.rf.f34361e36eed0387584009e480f197f4.jpg (starts with 'x')
# Skipping file: X1343101_L1_jpg.rf.16d6912fe981f51c9673601de373b7b2.jpg (starts with 'x')
# Skipping file: X220869_L1_jpg.rf.9cbe88e729658acd7c41247e9ba5cb87.jpg (starts with 'x')
# Skipping file: X1348043_L4_jpg.rf.076baa57c3e9366a198ea2ac05fdd7fd.jpg (starts with 'x')
# Skipping file: X1339703_L1_jpg.rf.e289388ae1f655226d2876cc3c1c9e10.jpg (starts with 'x')
# Skipping file: X872169_L2_jpg.rf.b882785f5c97a8cfbb232f2b06d6e2fb.jpg (starts with 'x')
# Skipping file: X1308442_L5_jpg.rf.dbd922be916937cf15ce36874c7ae500.jpg (starts with 'x')
# Skipping file: X594092_L5_jpg.rf.3a67d0a4ea254e4f435748a607d9fc97.jpg (starts with 'x')
# Skipping file: X820508_L4_jpg.rf.31a7f3329177e6d356156d1c953f13e8.jpg (starts with 'x')
#
# Processing: S832067_jpg.rf.36009f209a5eeedbb7e49728d0ef79ee.jpg
#   Preprocessed input tensor shape: (1, 416, 416, 1)
#   Generated mask shape: (416, 416)
#   Saved mask to: ../data/JUH_segmentation_output/train_masks/mask_S832067_jpg.rf.36009f209a5eeedbb7e49728d0ef79ee.png
#   Saved preprocessed image to: ../data/JUH_segmentation_output/train_preprocessed/preprocess_S832067_jpg.rf.36009f209a5eeedbb7e49728d0ef79ee.png
# Skipping file: X674093_L5_jpg.rf.8fc7c815b14051cd224038b46a6b4089.jpg (starts with 'x')
# Skipping file: X1077251_L1_jpg.rf.2b48e252d02f90451d2c2dce32700477.jpg (starts with 'x')
# Skipping file: X1117709_L1_jpg.rf.7303715d72b87266617f7fe5312bb55c.jpg (starts with 'x')
# Skipping file: X1059369_L3_jpg.rf.62224d2370c983d856fbcee67f3d6903.jpg (starts with 'x')
# Skipping file: X645014_L4_jpg.rf.68e154dc558af7fd71a0618fbc6e4016.jpg (starts with 'x')
# Skipping file: X996306-L2_jpg.rf.d7e092ade28b97a36469949bec3704b3.jpg (starts with 'x')
# Skipping file: X1006086_L5_jpg.rf.15d3e7c94ce7fdaaea864f594d025eb8.jpg (starts with 'x')
#
# Processing: S262360_jpg.rf.ab32921c0e060caec9a4438a4307c82d.jpg
#   Preprocessed input tensor shape: (1, 416, 416, 1)
#   Generated mask shape: (416, 416)
#   Saved mask to: ../data/JUH_segmentation_output/train_masks/mask_S262360_jpg.rf.ab32921c0e060caec9a4438a4307c82d.png
#   Saved preprocessed image to: ../data/JUH_segmentation_output/train_preprocessed/preprocess_S262360_jpg.rf.ab32921c0e060caec9a4438a4307c82d.png
# Skipping file: X1349309_L2_jpg.rf.5eb07b8c56c3bfd0dd314abbcff70a7d.jpg (starts with 'x')
#
# Processing: s1316011_jpg.rf.0b161d6ea209e3bbd8ff53f62a535e5b.jpg
#   Preprocessed input tensor shape: (1, 416, 416, 1)
#   Generated mask shape: (416, 416)
#   Saved mask to: ../data/JUH_segmentation_output/train_masks/mask_s1316011_jpg.rf.0b161d6ea209e3bbd8ff53f62a535e5b.png
#   Saved preprocessed image to: ../data/JUH_segmentation_output/train_preprocessed/preprocess_s1316011_jpg.rf.0b161d6ea209e3bbd8ff53f62a535e5b.png
# Skipping file: x1137008-L5_jpg.rf.bec90d50ffeb3520caec15c5db1b829b.jpg (starts with 'x')
# Skipping file: x1097675-L2_jpg.rf.9237fd0064aafb805ece733fe993685d.jpg (starts with 'x')
# Skipping file: X700791_L1_jpg.rf.b3299091de302771674f7cc2e40cb376.jpg (starts with 'x')
# Skipping file: X503305_L4_jpg.rf.a721a91181071fc255e4689c0b66557a.jpg (starts with 'x')
# Skipping file: X599459_L2_jpg.rf.e9e51a204b60f2f06b95a0e6345a0a76.jpg (starts with 'x')
# Skipping file: X1325050_L5_jpg.rf.9de9d0b053d17b25ac08b58425797831.jpg (starts with 'x')
# Skipping file: x1327418-L3_jpg.rf.8c1d5abd2a2bb9ccf5bc7665ce99ed2f.jpg (starts with 'x')
#
# Processing: S796648_jpg.rf.9df7767aebff612b614d43bc7d04a384.jpg
#   Preprocessed input tensor shape: (1, 416, 416, 1)
#   Generated mask shape: (416, 416)
#   Saved mask to: ../data/JUH_segmentation_output/train_masks/mask_
jpg
#   Preprocessed input tensor shape: (1, 416, 416, 1)
#   Generated mask shape: (416, 416)
#   Saved mask to: ../data/JUH_segmentation_output/train_masks/mask_s507037-L3_jpg.rf.80c4b39cfc8262a6bc9ddbcb51573fcd.png
#   Saved preprocessed image to: ../data/JUH_segmentation_output/train_preprocessed/preprocess_s507037-L3_jpg.rf.80c4b39cfc8262a6bc9ddbcb51573fcd.png
# Skipping file: X729501_L2_jpg.rf.8300abea62c1ae1498e444ac3f0896e6.jpg (starts with 'x')
# Skipping file: x1263421-L3_jpg.rf.93ec646f8b9f2877be740a309512a76f.jpg (starts with 'x')
# Skipping file: X232815_L5_jpg.rf.bcf75d8b4db9230a3708d6ce116d5d68.jpg (starts with 'x')
# Skipping file: x8976-L5_jpg.rf.532f0e9f7a41a6f6e670a14f03c92bfa.jpg (starts with 'x')
# Skipping file: X1234888_L5_jpg.rf.9d88ecb1c43f7536cd7122965430136f.jpg (starts with 'x')
# Skipping file: X301872_L3_jpg.rf.3aa2b1b311bf60888d8f7d1c186c0a8b.jpg (starts with 'x')
# Skipping file: X426915_L4_jpg.rf.48cce8f10aadf96ea0d7891fb9e20e4f.jpg (starts with 'x')
# Skipping file: x1327418-L1_jpg.rf.374ceedea66f41471912fe79abadde7d.jpg (starts with 'x')
# Skipping file: X1164300_L1_jpg.rf.063ba4a71b85788e39217492de905206.jpg (starts with 'x')
# Skipping file: X220869_L5_jpg.rf.9440f15a036f8a0f08dae07f69b2fafa.jpg (starts with 'x')
# Skipping file: X807108_L5_jpg.rf.44cf48f88fb5c78fdbf2c9d3df665777.jpg (starts with 'x')
# Skipping file: x8976-L2_jpg.rf.b51028efa6b708979cdb24f19848248b.jpg (starts with 'x')
# Skipping file: X1191502_L3_jpg.rf.aca4935b87ba7ee35b2d510b50641351.jpg (starts with 'x')
# Skipping file: X616751_L2_jpg.rf.776ebb1af0a1d1a5217f8bfd318c79a9.jpg (starts with 'x')
#
# Processing: S1348035_L4-L5_jpg.rf.5bcd12cb8e1f5628c5196a70444641f0.jpg
#   Preprocessed input tensor shape: (1, 416, 416, 1)
#   Generated mask shape: (416, 416)
#   Saved mask to: ../data/JUH_segmentation_output/train_masks/mask_S1348035_L4-L5_jpg.rf.5bcd12cb8e1f5628c5196a70444641f0.png
#   Saved preprocessed image to: ../data/JUH_segmentation_output/train_preprocessed/preprocess_S1348035_L4-L5_jpg.rf.5bcd12cb8e1f5628c5196a70444641f0.png
#
# Processing: S1191268_jpg.rf.51ce536b00351e8f86339d3f2717be0c.jpg
#   Preprocessed input tensor shape: (1, 416, 416, 1)
#   Generated mask shape: (416, 416)
#   Saved mask to: ../data/JUH_segmentation_output/train_masks/mask_S1191268_jpg.rf.51ce536b00351e8f86339d3f2717be0c.png
#   Saved preprocessed image to: ../data/JUH_segmentation_output/train_preprocessed/preprocess_S1191268_jpg.rf.51ce536b00351e8f86339d3f2717be0c.png
# Skipping file: XX642720_L5_jpg.rf.e8016fafaf42a32b5d5f7512fcaa10de.jpg (starts with 'x')
# Skipping file: x671294-L2_jpg.rf.b241a95aef262fafc557965bca8650e2.jpg (starts with 'x')
# Skipping file: X344138_L3_jpg.rf.e16a6713ba33ef888b145767c3b50e9b.jpg (starts with 'x')
# Skipping file: X573113_L4_jpg.rf.7cee291133e3d194ff8f1f027fd8fd89.jpg (starts with 'x')
# Skipping file: x66680-L5_jpg.rf.5d2be73f07d98449dcdbf38fcaaa019a.jpg (starts with 'x')
#
# Processing: S997065_jpg.rf.7324296700873cf56a296b4b440d1f49.jpg
#   Preprocessed input tensor shape: (1, 416, 416, 1)
#   Generated mask shape: (416, 416)
#   Saved mask to: ../data/JUH_segmentation_output/train_masks/mask_S997065_jpg.rf.7324296700873cf56a296b4b440d1f49.png
#   Saved preprocessed image to: ../data/JUH_segmentation_output/train_preprocessed/preprocess_S997065_jpg.rf.7324296700873cf56a296b4b440d1f49.png
# Skipping file: X554663_L1_jpg.rf.71497fbdafa8c4d38dfbf59fc3da9e17.jpg (starts with 'x')
# Skipping file: X1328645_L2_jpg.rf.f1ca85a489fd36491bb544a02e1c33cf.jpg (starts with 'x')
#
# Processing: s958920_jpg.rf.a07383a74512d38ccec2cab810502ead.jpg
#   Preprocessed input tensor shape: (1, 416, 416, 1)
#   Generated mask shape: (416, 416)
#   Saved mask to: ../data/JUH_segmentation_output/train_masks/mask_s958920_jpg.rf.a07383a74512d38ccec2cab810502ead.png
#   Saved preprocessed image to: ../data/JUH_segmentation_output/train_preprocessed/preprocess_s958920_jpg.rf.a07383a74512d38ccec2cab810502ead.png
# Skipping file: X685678_L2_jpg.rf.1b6f140863ba7f354b7f2768f64efaf8.jpg (starts with 'x')
#
# Processing: S737905_L4-1-_jpg.rf.11a5cc4f8c98654823487ae4ba21d468.jpg
#   Preprocessed input tensor shape: (1, 416, 416, 1)
#   Generated mask shape: (416, 416)
#   Saved mask to: ../data/JUH_segmentation_output/train_masks/mask_S737905_L4-1-_jpg.rf.11a5cc4f8c98654823487ae4ba21d468.png
#   Saved preprocessed image to: ../data/JUH_segmentation_output/train_preprocessed/preprocess_S737905_L4-1-_jpg.rf.11a5cc4f8c98654823487ae4ba21d468.png
#
# Processing: S1164300_jpg.rf.fac844cc395bb3a0260e6ab5c288fe7b.jpg
#   Preprocessed input tensor shape: (1, 416, 416, 1)
#   Generated mask shape: (416, 416)
#   Saved mask to: ../data/JUH_segmentation_output/train_masks/mask_S1164300_jpg.rf.fac844cc395bb3a0260e6ab5c288fe7b.png
#   Saved preprocessed image to: ../data/JUH_segmentation_output/train_preprocessed/preprocess_S1164300_jpg.rf.fac844cc395bb3a0260e6ab5c288fe7b.png
# Skipping file: x751486-L1_jpg.rf.27ee9b02e68d9b17da1a3e530cbae892.jpg (starts with 'x')
# Skipping file: X718798_L2_jpg.rf.55d80f1764890e07e6546144fa31b2f0.jpg (starts with 'x')
# Skipping file: X1121548_L2_jpg.rf.07bcbd66c2b866821aac4f1e1b0d8330.jpg (starts with 'x')
#
# Processing: s1309776-L4_jpg.rf.e39294bab8716f83b5b668370dff3551.jpg
#   Preprocessed input tensor shape: (1, 416, 416, 1)
#   Generated mask shape: (416, 416)
#   Saved mask to: ../data/JUH_segmentation_output/train_masks/mask_s1309776-L4_jpg.rf.e39294bab8716f83b5b668370dff3551.png
#   Saved preprocessed image to: ../data/JUH_segmentation_output/train_preprocessed/preprocess_s1309776-L4_jpg.rf.e39294bab8716f83b5b668370dff3551.png
# Skipping file: X190929_L2_jpg.rf.0e0da8ee07e4845f6c46e6127712d66a.jpg (starts with 'x')
# Skipping file: x853295-L1_jpg.rf.e4fb659e48d0d14664ec6ba3032ba5cc.jpg (starts with 'x')
# Skipping file: X1313227_L3_jpg.rf.18acf769b76dafa1d8e4310023ffc47a.jpg (starts with 'x')
#
# Processing: S836297_jpg.rf.8fb10c020aa980a00f0fe4927a2f1ea4.jpg
#   Preprocessed input tensor shape: (1, 416, 416, 1)
#   Generated mask shape: (416, 416)
#   Saved mask to: ../data/JUH_segmentation_output/train_masks/mask_S836297_jpg.rf.8fb10c020aa980a00f0fe4927a2f1ea4.png
#   Saved preprocessed image to: ../data/JUH_segmentation_output/train_preprocessed/preprocess_S836297_jpg.rf.8fb10c020aa980a00f0fe4927a2f1ea4.png
# Skipping file: X796648_L4_jpg.rf.e8804d4fe3586e5dbae3f1438e9a21d8.jpg (starts with 'x')
# Skipping file: X1355923_L5_jpg.rf.98508416ca5197b031dc9f9243b79ac3.jpg (starts with 'x')
# Skipping file: X291168_L4_jpg.rf.f9b70de3c87324d4683312bcb5511de5.jpg (starts with 'x')
# Skipping file: X965660_L4_jpg.rf.6baed0ce4f799a3e6ca9a77c0d7db8ed.jpg (starts with 'x')
# Skipping file: X560918_L2_jpg.rf.42910d86706d28d4168f84dd9ca90f4f.jpg (starts with 'x')
# Skipping file: X13482210_L5_jpg.rf.cb34ae30789724ed2df49ebadb55b8a7.jpg (starts with 'x')
#
# Processing: S114899_L1-L5-1-_jpg.rf.586ebd24e3e0f9b048e4e47df5366432.jpg
#   Preprocessed input tensor shape: (1, 416, 416, 1)
#   Generated mask shape: (416, 416)
#   Saved mask to: ../data/JUH_segmentation_output/train_masks/mask_S114899_L1-L5-1-_jpg.rf.586ebd24e3e0f9b048e4e47df5366432.png
#   Saved preprocessed image to: ../data/JUH_segmentation_output/train_preprocessed/preprocess_
png
#   Saved preprocessed image to: ../data/JUH_segmentation_output/train_preprocessed/preprocess_S319111_jpg.rf.f72b73f2c6b3a0d1fc22b8ae3a046f33.png
# Skipping file: X112911_L2_jpg.rf.7ac07f9823128a99101ef3af31f325d7.jpg (starts with 'x')
# Skipping file: X1333170_L1_jpg.rf.e84363833c4389aaad54fda5b309ebf7.jpg (starts with 'x')
# Skipping file: X1339760_L1_jpg.rf.cef060e851083dc733722b25bd05e1e2.jpg (starts with 'x')
# Skipping file: X1277384_L5_jpg.rf.a14f5e6ef42f7f592db397217afd33d9.jpg (starts with 'x')
#
# Processing: S578594_jpg.rf.2a3107637dc9d42a0afffee1f002c72f.jpg
#   Preprocessed input tensor shape: (1, 416, 416, 1)
#   Generated mask shape: (416, 416)
#   Saved mask to: ../data/JUH_segmentation_output/train_masks/mask_S578594_jpg.rf.2a3107637dc9d42a0afffee1f002c72f.png
#   Saved preprocessed image to: ../data/JUH_segmentation_output/train_preprocessed/preprocess_S578594_jpg.rf.2a3107637dc9d42a0afffee1f002c72f.png
# Skipping file: X1277384_L2_jpg.rf.ae3f7782b0f47b9514c6306442c6cfa8.jpg (starts with 'x')
# Skipping file: X583694_L4_jpg.rf.6f95507804364f7d4ab1ea65af74c6cb.jpg (starts with 'x')
# Skipping file: X996306-L1_jpg.rf.e440b89a98debed17dac4f86d399f44b.jpg (starts with 'x')
# Skipping file: X1311818_L1_jpg.rf.ed68cb23a03901a1c347c3e3b029117a.jpg (starts with 'x')
# Skipping file: x1263421-L1_jpg.rf.d21f71d6cd7c5509d41d5e2cbed89008.jpg (starts with 'x')
#
# Processing: S807432_jpg.rf.fa51457c56e6afb839d66b00c01b747c.jpg
#   Preprocessed input tensor shape: (1, 416, 416, 1)
#   Generated mask shape: (416, 416)
#   Saved mask to: ../data/JUH_segmentation_output/train_masks/mask_S807432_jpg.rf.fa51457c56e6afb839d66b00c01b747c.png
#   Saved preprocessed image to: ../data/JUH_segmentation_output/train_preprocessed/preprocess_S807432_jpg.rf.fa51457c56e6afb839d66b00c01b747c.png
# Skipping file: X752446_L5_jpg.rf.922d2ac2fd07b6f702f1073b9fbe4a1d.jpg (starts with 'x')
# Skipping file: X568201_L3_jpg.rf.58c75fc5d7a08ffa38e8d0d65475acf7.jpg (starts with 'x')
# Skipping file: X554663_L3_jpg.rf.ec184de7bd24926912c1a8e90a45e9a5.jpg (starts with 'x')
# Skipping file: X280965_L1_jpg.rf.45c94594a74e5490c5ccfe5e7815956d.jpg (starts with 'x')
# Skipping file: X309199_L3_jpg.rf.60c0a8b1455be2d2d7c5ce53e4e478f3.jpg (starts with 'x')
# Skipping file: x1290486-L4_jpg.rf.ca3bd0005fa30f5bef4110d9b6041bc8.jpg (starts with 'x')
#
# Processing: S1270443_jpg.rf.937e82eb75407aa0c2db573fc12da878.jpg
#   Preprocessed input tensor shape: (1, 416, 416, 1)
#   Generated mask shape: (416, 416)
#   Saved mask to: ../data/JUH_segmentation_output/train_masks/mask_S1270443_jpg.rf.937e82eb75407aa0c2db573fc12da878.png
#   Saved preprocessed image to: ../data/JUH_segmentation_output/train_preprocessed/preprocess_S1270443_jpg.rf.937e82eb75407aa0c2db573fc12da878.png
#
# Processing: S1191268-RIGHT_jpg.rf.34677dca042a0c09694db67c1eee8420.jpg
#   Preprocessed input tensor shape: (1, 416, 416, 1)
#   Generated mask shape: (416, 416)
#   Saved mask to: ../data/JUH_segmentation_output/train_masks/mask_S1191268-RIGHT_jpg.rf.34677dca042a0c09694db67c1eee8420.png
#   Saved preprocessed image to: ../data/JUH_segmentation_output/train_preprocessed/preprocess_S1191268-RIGHT_jpg.rf.34677dca042a0c09694db67c1eee8420.png
# Skipping file: X105279_L5_jpg.rf.d22651b56c52adf15e11462aafe74055.jpg (starts with 'x')
#
# Processing: S1154830_jpg.rf.176e3375040c9e428b387e6608232998.jpg
#   Preprocessed input tensor shape: (1, 416, 416, 1)
#   Generated mask shape: (416, 416)
#   Saved mask to: ../data/JUH_segmentation_output/train_masks/mask_S1154830_jpg.rf.176e3375040c9e428b387e6608232998.png
#   Saved preprocessed image to: ../data/JUH_segmentation_output/train_preprocessed/preprocess_S1154830_jpg.rf.176e3375040c9e428b387e6608232998.png
# Skipping file: X1117709_L4_jpg.rf.46d1ae7eb524470f1e9613e352672788.jpg (starts with 'x')
# Skipping file: X1286457_L4_jpg.rf.00a5768be43ec72de8fcc2f0193897af.jpg (starts with 'x')
# Skipping file: X1263585_L4_jpg.rf.9916c8dd55072cc6ace4929290288563.jpg (starts with 'x')
#
# Processing: S1155577_L4L5_jpg.rf.9ceec7eb507baa0a02a5d61b382ecbe1.jpg
#   Preprocessed input tensor shape: (1, 416, 416, 1)
#   Generated mask shape: (416, 416)
#   Saved mask to: ../data/JUH_segmentation_output/train_masks/mask_S1155577_L4L5_jpg.rf.9ceec7eb507baa0a02a5d61b382ecbe1.png
#   Saved preprocessed image to: ../data/JUH_segmentation_output/train_preprocessed/preprocess_S1155577_L4L5_jpg.rf.9ceec7eb507baa0a02a5d61b382ecbe1.png
#
# Processing: S847497_jpg.rf.34b8b12ab4dc116acffa283b527fee86.jpg
#   Preprocessed input tensor shape: (1, 416, 416, 1)
#   Generated mask shape: (416, 416)
#   Saved mask to: ../data/JUH_segmentation_output/train_masks/mask_S847497_jpg.rf.34b8b12ab4dc116acffa283b527fee86.png
#   Saved preprocessed image to: ../data/JUH_segmentation_output/train_preprocessed/preprocess_S847497_jpg.rf.34b8b12ab4dc116acffa283b527fee86.png
# Skipping file: X947702_L3_jpg.rf.1722b5c4e370b6334fe20998c17fb1b8.jpg (starts with 'x')
# Skipping file: X1131563_L3_jpg.rf.00394e358a1b099f93b4cb050e65618c.jpg (starts with 'x')
# Skipping file: X669335_L5_jpg.rf.f4419d39174585c77d1a98227ecba9ec.jpg (starts with 'x')
# Skipping file: x308483-L5_jpg.rf.f7d999ddfd8a80c236ebd78007f70ca3.jpg (starts with 'x')
# Skipping file: X1342072_L3_jpg.rf.6d66b5ad55a23b883e6d3116519d880e.jpg (starts with 'x')
#
# Processing: S1355573_jpg.rf.5bc62b248150a648f7ef88384e2542c9.jpg
#   Preprocessed input tensor shape: (1, 416, 416, 1)
#   Generated mask shape: (416, 416)
#   Saved mask to: ../data/JUH_segmentation_output/train_masks/mask_S1355573_jpg.rf.5bc62b248150a648f7ef88384e2542c9.png
#   Saved preprocessed image to: ../data/JUH_segmentation_output/train_preprocessed/preprocess_S1355573_jpg.rf.5bc62b248150a648f7ef88384e2542c9.png
# Skipping file: x667334-L3_jpg.rf.14ea4adce6154af01e70845755b8ffcb.jpg (starts with 'x')
# Skipping file: X13482210_L4_jpg.rf.be1f06a47c8bdc5a51cb061124ea3ed9.jpg (starts with 'x')
# Skipping file: X568201_L1_jpg.rf.c1bbc9df63e86e5bfc457f1b0b738804.jpg (starts with 'x')
# Skipping file: X1046811_L1_jpg.rf.03e347840bc8f08d572785b9a407ca37.jpg (starts with 'x')
#
# Processing: S944353_L4L_jpg.rf.243380e8f5f25b28d5c7c234a07fe95e.jpg
#   Preprocessed input tensor shape: (1, 416, 416, 1)
#   Generated mask shape: (416, 416)
# ...
#   Saved preprocessed image to: ../data/JUH_segmentation_output/train_preprocessed/preprocess_S112911_L4-L5R_jpg.rf.0ceb0fb4938658978fae261e9d7bd76a.png
# Skipping file: X928843_L3_jpg.rf.949578a680bf7ce982d07f9242e88f73.jpg (starts with 'x')
# Skipping file: x236173-L2_jpg.rf.eb998740ff343c4eca6ccbf91fed5668.jpg (starts with 'x')
# Skipping file: X902452_L4_jpg.rf.cae032cd1e210cbd2cdd7a1fffbd8680.jpg (starts with 'x')
# Skipping file: X1082425_L5_jpg.rf.80a7d1ef6ea02c8cd10c7db6e1a048c5.jpg (starts with 'x')
#
# Processing: S707828_jpg.rf.0a708d72ab5fd869c362216f93d1253e.jpg
#   Preprocessed input tensor shape: (1, 416, 416, 1)
#   Generated mask shape: (416, 416)
#   Saved mask to: ../data/JUH_segmentation_output/train_masks/mask_S707828_jpg.rf.0a708d72ab5fd869c362216f93d1253e.png
#   Saved preprocessed image to: ../data/JUH_segmentation_output/train_preprocessed/preprocess_S707828_jpg.rf.0a708d72ab5fd869c362216f93d1253e.png
# Skipping file: X1347225_L5_jpg.rf.a96edd635cfad4e85e4dfb6d1e8f9c56.jpg (starts with 'x')
# Skipping file: X832728_L5_jpg.rf.91b4b3c1add98d52ecb8b54172bb9d06.jpg (starts with 'x')
# Skipping file: X103874-L5_jpg.rf.dc4e0f9ee8fae35d872c817d966dd75a.jpg (starts with 'x')
# Skipping file: x831491-L5_jpg.rf.b1859084af6181482911778d831e166a.jpg (starts with 'x')
# Skipping file: X785034_L1_jpg.rf.9552bff31ec8902749d7cd5869099bd6.jpg (starts with 'x')
# Skipping file: X262360_L4_jpg.rf.2c8a0a916c9d0c177385e96faf19cbbf.jpg (starts with 'x')
#
# Processing: S112911_L4-L5_jpg.rf.e1a299bac87e8ee13eaa330b6f8596d2.jpg
#   Preprocessed input tensor shape: (1, 416, 416, 1)
#   Generated mask shape: (416, 416)
#   Saved mask to: ../data/JUH_segmentation_output/train_masks/mask_S112911_L4-L5_jpg.rf.e1a299bac87e8ee13eaa330b6f8596d2.png
#   Saved preprocessed image to: ../data/JUH_segmentation_output/train_preprocessed/preprocess_S112911_L4-L5_jpg.rf.e1a299bac87e8ee13eaa330b6f8596d2.png
# Skipping file: X902102_L5_jpg.rf.52c668516becbf6debb06f5e448fbcc3.jpg (starts with 'x')
# Skipping file: X1156371_L3_jpg.rf.5e1cbc48d402de94fbeb8d7806d9505f.jpg (starts with 'x')
# Skipping file: X1000188_L3_jpg.rf.ca2836433a6019618a48ea4bd9a78e52.jpg (starts with 'x')
#
# Processing: S1270443-LEFT_jpg.rf.3bf4fa930e2b0dfe71aec0a9519b7f74.jpg
#   Preprocessed input tensor shape: (1, 416, 416, 1)
#   Generated mask shape: (416, 416)
#   Saved mask to: ../data/JUH_segmentation_output/train_masks/mask_S1270443-LEFT_jpg.rf.3bf4fa930e2b0dfe71aec0a9519b7f74.png
#   Saved preprocessed image to: ../data/JUH_segmentation_output/train_preprocessed/preprocess_S1270443-LEFT_jpg.rf.3bf4fa930e2b0dfe71aec0a9519b7f74.png
#
# Processing: s1332547-L4_jpg.rf.86dc229238d8b57b252f121fcce0924a.jpg
#   Preprocessed input tensor shape: (1, 416, 416, 1)
#   Generated mask shape: (416, 416)
#   Saved mask to: ../data/JUH_segmentation_output/train_masks/mask_s1332547-L4_jpg.rf.86dc229238d8b57b252f121fcce0924a.png
#   Saved preprocessed image to: ../data/JUH_segmentation_output/train_preprocessed/preprocess_s1332547-L4_jpg.rf.86dc229238d8b57b252f121fcce0924a.png
#
# Processing: S528764_jpg.rf.3f9551b36b3489093f63ca7c2fedad00.jpg
#   Preprocessed input tensor shape: (1, 416, 416, 1)
#   Generated mask shape: (416, 416)
#   Saved mask to: ../data/JUH_segmentation_output/train_masks/mask_S528764_jpg.rf.3f9551b36b3489093f63ca7c2fedad00.png
#   Saved preprocessed image to: ../data/JUH_segmentation_output/train_preprocessed/preprocess_S528764_jpg.rf.3f9551b36b3489093f63ca7c2fedad00.png
# Skipping file: x763125-L4_jpg.rf.43c5f24f065fab56738a69e17f3285c3.jpg (starts with 'x')
# Skipping file: X536822_L5_jpg.rf.3bf9f7be860dd43843e2e88f8d63b59b.jpg (starts with 'x')
# Skipping file: x751486-L3_jpg.rf.f873ba54ec30ee9e26722582a0e380b4.jpg (starts with 'x')
# Skipping file: X552630_L3_jpg.rf.b5fc62c6e0bc233a290bc174b28247e3.jpg (starts with 'x')
#
# Processing: s580592-L4_jpg.rf.f32fc6169d3851afa7a70283ed8dc91a.jpg
#   Preprocessed input tensor shape: (1, 416, 416, 1)
#   Generated mask shape: (416, 416)
#   Saved mask to: ../data/JUH_segmentation_output/train_masks/mask_s580592-L4_jpg.rf.f32fc6169d3851afa7a70283ed8dc91a.png
#   Saved preprocessed image to: ../data/JUH_segmentation_output/train_preprocessed/preprocess_s580592-L4_jpg.rf.f32fc6169d3851afa7a70283ed8dc91a.png
# Skipping file: x1043012-L1_jpg.rf.671102aea4bfde6da93a81e4d65b3588.jpg (starts with 'x')
# Skipping file: X374690_L2_jpg.rf.b267b1ca5fbddd242e80613da26167fc.jpg (starts with 'x')
# Skipping file: x614621-L2_jpg.rf.385702f44c3db1ec46546147b34cc639.jpg (starts with 'x')
# Skipping file: X1164300_L4_jpg.rf.980fd2ea2dd44f03ebb6aa1aa4ec41ae.jpg (starts with 'x')
# Skipping file: X811190_L1_jpg.rf.c2e9dbfd011f3c305cfe0df31293c624.jpg (starts with 'x')
#
# Processing: s649810-L3R_jpg.rf.51564513c8d2d87bb005a63e44b03b12.jpg
#   Preprocessed input tensor shape: (1, 416, 416, 1)
#   Generated mask shape: (416, 416)
#   Saved mask to: ../data/JUH_segmentation_output/train_masks/mask_s649810-L3R_jpg.rf.51564513c8d2d87bb005a63e44b03b12.png
#   Saved preprocessed image to: ../data/JUH_segmentation_output/train_preprocessed/preprocess_s649810-L3R_jpg.rf.51564513c8d2d87bb005a63e44b03b12.png
# Skipping file: X660388_L2_jpg.rf.765167c732595d0717df20e00ae1885d.jpg (starts with 'x')
#
# Processing: S197782_jpg.rf.b0af0b093168a0c29bec3c10e3c7c5a9.jpg
#   Preprocessed input tensor shape: (1, 416, 416, 1)
#   Generated mask shape: (416, 416)
#   Saved mask to: ../data/JUH_segmentation_output/train_masks/mask_S197782_jpg.rf.b0af0b093168a0c29bec3c10e3c7c5a9.png
#   Saved preprocessed image to: ../data/JUH_segmentation_output/train_preprocessed/preprocess_S197782_jpg.rf.b0af0b093168a0c29bec3c10e3c7c5a9.png
# Skipping file: x1121324-L5_jpg.rf.bf16394afca24b760159789784e4b6d4.jpg (starts with 'x')
# Skipping file: X1042543_L4_jpg.rf.11bf305b7488e7e3f899f7891b751b12.jpg (starts with 'x')
#
# Processing: s667334-L2_jpg.rf.b82909db71cf590d461f56161ccb5964.jpg
#   Preprocessed input tensor shape: (1, 416, 416, 1)
#   Generated mask shape: (416, 416)
#   Saved mask to: ../data/JUH_segmentation_output/train_masks/mask_s667334-L2_jpg.rf.b82909db71cf590d461f56161ccb5964.png
#   Saved preprocessed image to: ../data/JUH_segmentation_output/train_preprocessed/preprocess_s667334-L2_jpg.rf.b82909db71cf590d461f56161ccb5964.png
# Skipping file: X976187_L3_jpg.rf.541a60df7c8129f9b961a7ff95cb83c0.jpg (starts with 'x')
# Skipping file: X830981_L2_jpg.rf.3bad28482732936302c2865cd75b49e6.jpg (starts with 'x')
# Skipping file: X380958_L1_jpg.rf.0b2dfda850a314b4b32230d097be40d8.jpg (starts with 'x')
# Skipping file: X516136-L1_jpg.rf.cf0f9a31448bfaa9af2e2762d4287afb.jpg (starts with 'x')
# Skipping file: x245263-L3_jpg.rf.9986a45dece8afaffe23d724bdee913f.jpg (starts with 'x')
# Skipping file: X1342601_L2_jpg.rf.6226d60374bbb302388e8030fb956fcc.jpg (starts with 'x')
# Skipping file: X925325_L2_jpg.rf.704547e82a2ed1d8612397de5918bf5d.jpg (starts with 'x')
# Skipping file: X455481_L5_jpg.rf.9a3b541da905f9bc8a522d8c0911be27.jpg (starts with 'x')
# Skipping file: X1068298_L5_jpg.rf.3f28595836cd6b5230b5bbaf96d06323.jpg (starts with 'x')
# Skipping file: X1117709_L5_jpg.rf.6f0ca06bc739429003fbfcfcd954eaa4.jpg (starts with 'x')
# Skipping file: X1096547_L1_jpg.rf.810754d9dd1fa2786a22d81e6a2fc1e3.jpg (starts with 'x')
# Skipping file: X166715_L3_jpg.rf.dedbb2e43bef1fa756c105516f4ada3d.jpg (starts with 'x')
# Skipping file: X832728_L1_jpg.rf.86ab709048a40ba26646ff8a6096db67.jpg (starts with 'x')
# Skipping file: X1342069_L5_jpg.rf.25a1b0eba82c9a77f8ca835c06b7fa7f.jpg (starts with 'x')
# Skipping file: X689220_L1_jpg.rf.235573b045ac569f49a8d0b35d4279e4.jpg (starts with 'x')
# Skipping file: X608143_L5_jpg.rf.4a81e37c21f7389ecdb534f307c045b7.jpg (starts with 'x')
# Skipping file: X586271_L2_jpg.rf.3327835cd84e9cdaaeb034e4a6c22446.jpg (starts with 'x')
#
# Processing: S1257428_jpg.rf.b205dd760971f98cc64541f06c7f1ea1.jpg
#   Preprocessed input tensor shape: (1, 416, 416, 1)
#   Generated mask shape: (416, 416)
#   Saved mask to: ../data/JUH_segmentation_output/train_masks/mask_S1257428_jpg.rf.b205dd760971f98cc64541f06c7f1ea1.png
#   Saved preprocessed image to: ../data/JUH_segmentation_output/train_preprocessed/preprocess_S1257428_jpg.rf.b205dd760971f98cc64541f06c7f1ea1.png
# Skipping file: X986440_L1_jpg.rf.431ac1d4788bbc5306b288132dde04a8.jpg (starts with 'x')
# Skipping file: X928843_L5_jpg.rf.c0d9b9a00cce694e24d622566ab341dd.jpg (starts with 'x')
#
# Processing: S729501_L2-L5_jpg.rf.b2b64702e92f21ca99652f89b52dc4c6.jpg
#   Preprocessed input tensor shape: (1, 416, 416, 1)
#   Generated mask shape: (416, 416)
#   Saved mask to: ../data/JUH_segmentation_output/train_masks/mask_S729501_L2-L5_jpg.rf.b2b64702e92f21ca99652f89b52dc4c6.png
#   Saved preprocessed image to: ../data/JUH_segmentation_output/train_preprocessed/preprocess_S729501_L2-L5_jpg.rf.b2b64702e92f21ca99652f89b52dc4c6.png
# Skipping file: X1191268_L2_jpg.rf.3e40d213ecff0481f6de05f69b54d0c8.jpg (starts with 'x')
# Skipping file: x15839-L2_jpg.rf.987015229d233ae3c297f7e5d3029189.jpg (starts with 'x')
# Skipping file: x156966-L3_jpg.rf.8315c648cf1494bd4b4f991b8fbc3da5.jpg (starts with 'x')
#
# Processing: S1286457_L4L_jpg.rf.a850cd6b8108953c58d7383665180b20.jpg
#   Preprocessed input tensor shape: (1, 416, 416, 1)
#   Generated mask shape: (416, 416)
#   Saved mask to: ../data/JUH_segmentation_output/train_masks/mask_S1286457_L4L_jpg.rf.a850cd6b8108953c58d7383665180b20.png
#   Saved preprocessed image to: ../data/JUH_segmentation_output/train_preprocessed/preprocess_S1286457_L4L_jpg.rf.a850cd6b8108953c58d7383665180b20.png
# Skipping file: x1333389-L5_jpg.rf.ec334536ba6acd6104644fbd9f95571c.jpg (starts with 'x')
# Skipping file: X165184_L4_jpg.rf.b228af6fa95ce59b46156d4c850d3da3.jpg (starts with 'x')
# Skipping file: X1305997_L1_jpg.rf.29651fdcd1d69e3c465ab9b87f7716e1.jpg (starts with 'x')
#
# Processing: S819108_jpg.rf.058669eb69c22684a90f4555af58f851.jpg
#   Preprocessed input tensor shape: (1, 416, 416, 1)
#   Generated mask shape: (416, 416)
#   Saved mask to: ../data/JUH_segmentation_output/train_masks/mask_S819108_jpg.rf.058669eb69c22684a90f4555af58f851.png
#   Saved preprocessed image to: ../data/JUH_segmentation_output/train_preprocessed/preprocess_S819108_jpg.rf.058669eb69c22684a90f4555af58f851.png
#
# Processing: S656587_jpg.rf.d1e83cfa583a473c72ed0e7efbc343fb.jpg
#   Preprocessed input tensor shape: (1, 416, 416, 1)
#   Generated mask shape: (416, 416)
#   Saved mask to: ../data/JUH_segmentation_output/train_masks/mask_S656587_jpg.rf.d1e83cfa583a473c72ed0e7efbc343fb.png
#   Saved preprocessed image to: ../data/JUH_segmentation_output/train_preprocessed/preprocess_S656587_jpg.rf.d1e83cfa583a473c72ed0e7efbc343fb.png
# Skipping file: X590911_L2_jpg.rf.fd9e47b8261f31a6c225b56dbc9ce155.jpg (starts with 'x')
# Skipping file: X614434_L1_jpg.rf.5b45355d5d8865e66a5a3cad8b8bae67.jpg (starts with 'x')
# Skipping file: x562996-L4_jpg.rf.6bc4e645b4c8a678b439e70c3d118764.jpg (starts with 'x')
# Skipping file: x1337081-L3_jpg.rf.5aaf4b62d1aceaa4d09a7b1384575d4e.jpg (starts with 'x')
# Skipping file: X1263585_L2_jpg.rf.1aebf78ff23466c4d3e5dc082c7c9750.jpg (starts with 'x')
# Skipping file: X1340103_L4_jpg.rf.5f29421acb612ffdcaae0b9e0d47850d.jpg (starts with 'x')
# Skipping file: X426915_L5_jpg.rf.c55bd19a3a5593f283c0c59e7eeb0c3a.jpg (starts with 'x')
# Skipping file: x66680-L3_jpg.rf.d25a6d624bb0212851d758193fc090ba.jpg (starts with 'x')
#
# Processing: S45029_jpg.rf.b36a902d1e88fdd1d8f2214a9f786f88.jpg
#   Preprocessed input tensor shape: (1, 416, 416, 1)
#   Generated mask shape: (416, 416)
#   Saved mask to: ../data/JUH_segmentation_output/train_masks/mask_S45029_jpg.rf.b36a902d1e88fdd1d8f2214a9f786f88.png
#   Saved preprocessed image to: ../data/JUH_segmentation_output/train_preprocessed/preprocess_S45029_jpg.rf.b36a902d1e88fdd1d8f2214a9f786f88.png
#
# Processing: S516136_jpg.rf.30f7bea6c876ff2bee08e59f2e631460.jpg
#   Preprocessed input tensor shape: (1, 416, 416, 1)
#   Generated mask shape: (416, 416)
#   Saved mask to: ../data/JUH_segmentation_output/train_masks/mask_S516136_jpg.rf.30f7bea6c876ff2bee08e59f2e631460.png
#   Saved preprocessed image to: ../data/JUH_segmentation_output/train_preprocessed/preprocess_S516136_jpg.rf.30f7bea6c876ff2bee08e59f2e631460.png
# Skipping file: X866689_L4_jpg.rf.1f0100fb071731c8781adf3a3eb714cc.jpg (starts with 'x')
#
# Processing: S830339_jpg.rf.0ce697ed7cf713337e8e9a630197a17e.jpg
#   Preprocessed input tensor shape: (1, 416, 416, 1)
#   Generated mask shape: (416, 416)
#   Saved mask to: ../data/JUH_segmentation_output/train_masks/mask_S830339_jpg.rf.0ce697ed7cf713337e8e9a630197a17e.png
#   Saved preprocessed image to: ../data/JUH_segmentation_output/train_preprocessed/preprocess_S830339_jpg.rf.0ce697ed7cf713337e8e9a630197a17e.png
#
# Processing: S614434_jpg.rf.2fe8d881d6540f72083b2124d67f8108.jpg
#   Preprocessed input tensor shape: (1, 416, 416, 1)
#   Generated mask shape: (416, 416)
#   Saved mask to: ../data/JUH_segmentation_output/train_masks/mask_S614434_jpg.rf.2fe8d881d6540f72083b2124d67f8108.png
#   Saved preprocessed image to: ../data/JUH_segmentation_output/train_preprocessed/preprocess_S614434_jpg.rf.2fe8d881d6540f72083b2124d67f8108.png
#
# Processing: s1115015-L_jpg.rf.daae9231e2f92f2ddf87ae4322bce4db.jpg
#   Preprocessed input tensor shape: (1, 416, 416, 1)
#   Generated mask shape: (416, 416)
#   Saved mask to: ../data/JUH_segmentation_output/train_masks/mask_s1115015-L_jpg.rf.daae9231e2f92f2ddf87ae4322bce4db.png
#   Saved preprocessed image to: ../data/JUH_segmentation_output/train_preprocessed/preprocess_s1115015-L_jpg.rf.daae9231e2f92f2ddf87ae4322bce4db.png
# Skipping file: X262949_L1_jpg.rf.45037a07218b823f5e6fd2dda360e050.jpg (starts with 'x')
#
# Processing: S1305997_jpg.rf.3b7ab5fa1d80739f72b6146acff39b04.jpg
#   Preprocessed input tensor shape: (1, 416, 416, 1)
#   Generated mask shape: (416, 416)
#   Saved mask to: ../data/JUH_segmentation_output/train_masks/mask_S1305997_jpg.rf.3b7ab5fa1d80739f72b6146acff39b04.png
#   Saved preprocessed image to: ../data/JUH_segmentation_output/train_preprocessed/preprocess_S1305997_jpg.rf.3b7ab5fa1d80739f72b6146acff39b04.png
# Skipping file: X536822_L4_jpg.rf.5c4c2e8a6ee22fd6e14709250c0c6079.jpg (starts with 'x')
#
# Processing: S500901_jpg.rf.3de2acd3e4bb69be2a02a1581fb237ff.jpg
#   Preprocessed input tensor shape: (1, 416, 416, 1)
#   Generated mask shape: (416, 416)
#   Saved mask to: ../data/JUH_segmentation_output/train_masks/mask_S500901_jpg.rf.3de2acd3e4bb69be2a02a1581fb237ff.png
#   Saved preprocessed image to: ../data/JUH_segmentation_output/train_preprocessed/preprocess_S500901_jpg.rf.3de2acd3e4bb69be2a02a1581fb237ff.png
# Skipping file: x1237642-L2_jpg.rf.ea705f134c621c2ddf8533ebefbee3bd.jpg (starts with 'x')
# Skipping file: x161120-L3_jpg.rf.e318f41941b7d7d341c278d7b6abff8e.jpg (starts with 'x')
# Skipping file: X280965_L4_jpg.rf.490f1dfd9f5e478ead6b2879a0bdb73f.jpg (starts with 'x')
#
# Processing: S491392_L3-L5_jpg.rf.f353a739a13d9bb888acdc1b1d88b9f8.jpg
#   Preprocessed input tensor shape: (1, 416, 416, 1)
#   Generated mask shape: (416, 416)
#   Saved mask to: ../data/JUH_segmentation_output/train_masks/mask_S491392_L3-L5_jpg.rf.f353a739a13d9bb888acdc1b1d88b9f8.png
#   Saved preprocessed image to: ../data/JUH_segmentation_output/train_preprocessed/preprocess_S491392_L3-L5_jpg.rf.f353a739a13d9bb888acdc1b1d88b9f8.png
# Skipping file: X296461_L1_jpg.rf.41dc8f7dfb26b56942f75331b3edee65.jpg (starts with 'x')
# Skipping file: x743852-L4_jpg.rf.795a53ca5b26a72055ba34cae30f5e88.jpg (starts with 'x')
# Skipping file: X992381_L4_jpg.rf.6d7f5a4fa3b24e556463b4274d8d4d3f.jpg (starts with 'x')
# Skipping file: X832728_L4_jpg.rf.9342f5a7e9ff5e3a7d3c188d04260cdf.jpg (starts with 'x')
# Skipping file: x614621-L3_jpg.rf.7d989cd6b8bcd44c74b1db507c4711b9.jpg (starts with 'x')
#
# Processing: s667334-L3_jpg.rf.e7320c21a897c9cd4f98fb51bbe39b37.jpg
#   Preprocessed input tensor shape: (1, 416, 416, 1)
#   Generated mask shape: (416, 416)
#   Saved mask to: ../data/JUH_segmentation_output/train_masks/mask_s667334-L3_jpg.rf.e7320c21a897c9cd4f98fb51bbe39b37.png
#   Saved preprocessed image to: ../data/JUH_segmentation_output/train_preprocessed/preprocess_s667334-L3_jpg.rf.e7320c21a897c9cd4f98fb51bbe39b37.png
#
# Finished processing. Processed: 645, Skipped: 2273
